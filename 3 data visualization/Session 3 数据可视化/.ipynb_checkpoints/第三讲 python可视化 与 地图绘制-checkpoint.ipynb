# %% [markdown]
# # Session 3 Python 可视化

# %% [markdown]
# ## 关于 清华大学计算社会科学平台
#
# - 为了提升清华计算社会科学研究的整体水平，营造“创新、共享、开放、合作”的大数据科研环境，打造大数据时代清华社会科学发展的独特品牌，2017年5月，清华大学社科学院决定联合清华其他社科类学院系、清华大学数据科学研究院建设“清华大学计算社会科学平台（Tsinghua-Computational Social Science Institution）”,以服务于社科学院在“十三五”期间顺利实现“弯道超车”，建成国际一流社会科学的发展目标。
#
# - “清华大学计算社会科学平台”将充分利用清华大学、大数据产业界、相关政府部门的多样化资源条件，组织经济学、心理学、社会学、政治学、国际关系等多学科研究团队系统地开展将大数据资源、大数据方法和大数据方案应用于社会科学研究，为社会科学研究范式转换、促进重大经济社会问题解决提供理论和应用知识。

# %% [markdown]
# [咦？为什么这段看起来不一样了。] - Markdown language：https://www.markdownguide.org/cheat-sheet/
# - 注意切换页面上方的下拉菜单code->markdown

# %% [markdown]
# ## 本节课程主旨：使用matplotlib, seaborn, geopandas 进行数据可视化，以及官方文档的使用

# %%
# ! pip install matplotlib
# ! pip install seaborn


# 导入绘图模块
import matplotlib  #https://www.matplotlib.org.cn/tutorials/#%E5%BA%8F%E8%A8%80
import matplotlib.pyplot as plt # 导入模块 matplotlib.pyplot，并简写成 plt, 这样之后不需要输入一长串
import seaborn as sns # 导入作图模块 seaborn

# 导入数据处理模块
import pandas as pd # 导入模块 pandas（之前使用的用于整理表格、数据分析的模块），并简写成 pd
import numpy as np # 导入模块 numpy（之前使用的用于整理表格、数据分析的模块），并简写成 np

import warnings
warnings.filterwarnings("ignore") # 一些警告信息可以不保留

# %%
# 看看 plt module里面有什么东西？

print(type(plt), plt) # module -> 工具包
# Out:
# <class 'module'> <module 'matplotlib.pyplot' from '/Users/siyaozheng/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
plt.figure # 取出一个工具：找到工具包.拿出工具（根据需求让工具变得最为顺手的配置）
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
# 建立画布 canvas
# 这一步非必要，但推荐设置：plt没有指定画布和区域也能作图，但是会影响作图效果

fig = plt.figure(figsize = (20, 12)) # 此处的 12 和 8 的单位是inch，1 inch 约等于 2.5 cm

fig, axes = plt.subplots(1,1) # 在画布上建立一个 1*1 的格子
# 这个写法和平时有点不一样：把元组（tuple）还原为两个variable的过程

plt.show() # show 出来的就是 fig

# %%
print(axes, type(axes)) # 在哪里画图（画图的格子）
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755) <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
print(type(fig)) # 整个图
# Out:
# <class 'matplotlib.figure.Figure'>

# %% [markdown]
# ### 感受一下这个图：
# ![图例](fig-axes.png)
#
# - cr: https://towardsdatascience.com/what-are-the-plt-and-ax-in-matplotlib-exactly-d2cf4bf164a9

# %%
# 在一张画布上建立多个图
fig, ax = plt.subplots(2, 2, 
                           sharex = True, 
                           sharey = True) # 这行的含义是，在画布fig上创建一个以 axes 为单位的 2 x 2 网格的 figure 
fig.suptitle('2*2 plots')
plt.show()

# %%
# 创建一个数据集
x = np.linspace(-5, 10, 50) #调用np.linspace是创建一个 numpy 数组，并记作 x。x 包含了从 -5 到 10 之间等间隔的 50 个值。
print(x)

type(x)
# Out:
# [-5.         -4.69387755 -4.3877551  -4.08163265 -3.7755102  -3.46938776
#  -3.16326531 -2.85714286 -2.55102041 -2.24489796 -1.93877551 -1.63265306
#  -1.32653061 -1.02040816 -0.71428571 -0.40816327 -0.10204082  0.20408163
#   0.51020408  0.81632653  1.12244898  1.42857143  1.73469388  2.04081633
#   2.34693878  2.65306122  2.95918367  3.26530612  3.57142857  3.87755102
#   4.18367347  4.48979592  4.79591837  5.10204082  5.40816327  5.71428571
#   6.02040816  6.32653061  6.63265306  6.93877551  7.24489796  7.55102041
#   7.85714286  8.16326531  8.46938776  8.7755102   9.08163265  9.3877551
#   9.69387755 10.        ]
# numpy.ndarray

# %%
# 创建一个函数，以及一个最朴素的基本图例
y1 = x + 3      # 曲线 y1
y1
# Out:
# array([-2.        , -1.69387755, -1.3877551 , -1.08163265, -0.7755102 ,
#        -0.46938776, -0.16326531,  0.14285714,  0.44897959,  0.75510204,
#         1.06122449,  1.36734694,  1.67346939,  1.97959184,  2.28571429,
#         2.59183673,  2.89795918,  3.20408163,  3.51020408,  3.81632653,
#         4.12244898,  4.42857143,  4.73469388,  5.04081633,  5.34693878,
#         5.65306122,  5.95918367,  6.26530612,  6.57142857,  6.87755102,
#         7.18367347,  7.48979592,  7.79591837,  8.10204082,  8.40816327,
#         8.71428571,  9.02040816,  9.32653061,  9.63265306,  9.93877551,
#        10.24489796, 10.55102041, 10.85714286, 11.16326531, 11.46938776,
#        11.7755102 , 12.08163265, 12.3877551 , 12.69387755, 13.        ])

# %%
# 绘制曲线
plt.figure()    # 建立一个画布
plt.plot(x, y1) # 绘制曲线
plt.show()

# %%
# 如果想设计更加丰富多彩的图：

# 简单的绘图
# x = np.linspace(-5, 10, 50) #调用np.linspace是创建一个 numpy 数组，并记作 x。x 包含了从 -5 到 10 之间等间隔的 50 个值。
# print(x)

# y1 = x + 3      # 曲线 y1
y2 = 3 - x      # 曲线 y2


######## 开始画图 ########

plt.figure()    # 建立一个画布
plt.plot(x, y1, linestyle = '-.', linewidth = 3.0, color = '#660874') # 绘制曲线 y1 # linestyle 标注了数据，linewidth 宽度
plt.plot(x, y2, marker = '*', markersize = 8.0,  color = '#9999ff') # 绘制曲线 y2 # 用 marker 标注的数据点

# 设置横轴的上下限
plt.xlim(-6, 12)
# 设置纵轴的上下限
plt.ylim(-20, 60)

# 设置横轴标签
plt.xlabel("X's label")
# 设置纵轴标签
plt.ylabel("Y's label")

plt.show() # 呈现图片


### 选取配色代码的网站
###  https://www.cnblogs.com/kuoAT/p/7198794.html

# 清华紫的RGB是 RGB 102 8 116, HEX代码 是 #660874

# %%
# 在一页上放两个图

fig, axes = plt.subplots(1, 2) # 建立一个1*2（一行，两列）的图, axes 可以随便改
y2 = 3 - x      # 画了一条曲线 y2

plt.figure()    # 建立一个画布
axes[0].plot(x, y1, color = 'red') #linewidth = 8.0
axes[0].set_title('y1 = x + 3') # 设置标题
axes[0].set_ylabel('common ylabel')
axes[1].plot(x, y2, color = 'blue')
axes[1].set_title('y2 = 3 - x')
axes[1].set_ylabel('common ylabel') # 还记得上面的设置横纵轴标签的问题吗？
fig.tight_layout()
plt.show() # 呈现图片

# %%
# 如何绘制更多的图？

fig, axs = plt.subplots(2, 2, 
                        sharex = True) # try removing sharex = True


# 现在设置4条不同的函数曲线
y1 = x + 3      
y2 = 3 - x    
y3 = 2 * x
y4 = x ** 2

plt.figure(figsize = (20, 12))    # 建立一个画布
axs[0,0].plot(x, y1, color = 'green')
axs[0,0].set_title('y1 = x + 3', fontsize = 20) # 改变字体大小
axs[0,1].plot(x, y2)
axs[0,1].set_title('y2 = 3 - x', color = 'b') # 改变颜色
axs[1,0].plot(x, y3)
axs[1,0].set_title('y3 = 2 * x', weight = 'bold') # 改变字体粗细
axs[1,1].plot(x, y4)
axs[1,1].set_title('y4 = x ^ 2') # default setting
fig.tight_layout() 

plt.show() # 呈现图片

# %%
# how to use different scale for the same axis
plt.figure(figsize = (8,8)) 
small = 12 # 设置一个字号值
medium = 15 # 设置一个字号值
plt.rc('axes', titlesize=small, labelsize=medium) # 设置轴
plt.rc('xtick', labelsize=small) # 设置x的scale   
plt.rc('ytick', labelsize=medium) # 设置y的scale


fig, ax1 = plt.subplots()
color = 'tab:blue' # Tableau Colors
ax1.set_xlabel('x')
ax1.set_ylabel('y = x + 3', color = color)
ax1.plot(x, y1, color=color)
ax1.tick_params(axis='y', 
                labelcolor=color)



ax2 = ax1.twinx()  # a very important step: second axes that shares the same x-axis

color = 'tab:pink'
ax2.set_ylabel('y = x ** 2', color=color)  # we already handled the x-label with ax1
ax2.plot(x, y4, color=color)
ax2.tick_params(axis='y', 
                labelcolor=color)
fig.suptitle('2*2 plots') #给图加标题 centered title

# fig.tight_layout()
plt.show()

# %%
# 用matplotlib绘图时的中文问题


# 简单的绘图
# x = np.linspace(-5, 10, 50) #调用np.linspace是创建一个 numpy 数组，并记作 x。x 包含了从 -5 到 10 之间等间隔的 50 个值。
# print(x)

# y1 = x + 3      # 曲线 y1
# y2 = 3 - x      # 曲线 y2

plt.figure()    # 建立一个画布
plt.plot(x, y1, linestyle = '-.', color = 'green', linewidth = 3.0) # 绘制曲线 y1 # linestyle 标注了数据，linewidth 宽度
plt.plot(x, y2, marker = '*', color = '#9999ff', markersize = 6.0) # 绘制曲线 y2 # 用 marker 标注的数据点


# 设置横轴的上下限
plt.xlim(-6, 12)
# 设置纵轴的上下限
plt.ylim(-20, 60)

# 设置横轴标签
plt.xlabel("横轴中文标签", size = 10) 
# 设置纵轴标签
plt.ylabel("纵轴中文标签", size = 10)

plt.show() # 呈现图片

# %%
# 用matplotlib绘图时的中文问题
# 通常可以使用配置字体库的方式，见 https://blog.csdn.net/qq_17753903/article/details/86260276
# 但这个比较复杂，初学者可以使用以下方法进行设置



# 设置字体路径的方式 - 方便起见，可以直接放在存储jupyter notebook的文件夹中。
zhfont = matplotlib.font_manager.FontProperties(fname = r'SourceHanSerifCN-Medium.ttf')



# 前面使用过的数据
# x = np.linspace(-5, 10, 50) #调用np.linspace是创建一个 numpy 数组，并记作 x。x 包含了从 -5 到 10 之间等间隔的 50 个值。
# print(x)
# y1 = x + 3      # 曲线 y1
# y2 = 3 - x      # 曲线 y2

plt.figure()    # 建立一个画布
plt.plot(x, y1, linestyle = '--', color = '#660874', linewidth = 3.0) # 绘制曲线 y1 # linestyle 标注了数据，linewidth 宽度
plt.plot(x, y2, marker = 'D', color = '#9999ff', markersize = 4.0) # 绘制曲线 y2 # 用 marker 标注的数据点


# 设置横轴的上下限，刻度
plt.xlim(-4, 8)
# 设置纵轴的上下限，刻度
plt.ylim(-10, 20)

# 设置横轴标签
plt.xlabel("横轴中文标签", fontproperties=zhfont, size = 15) # 通过 font properties 对字体的属性进行设置
# 设置纵轴标签
plt.ylabel("纵轴中文标签", fontproperties=zhfont, size = 15, rotation = 75) # 默认 rotation = 90

# 设置图例
plt.legend(labels = ['X', 'Y'], loc = 'upper right', fontsize = 10)

# 绘制散点(3, 6)
plt.scatter([3], [6], s=30, color="blue")      # s 为点的 size
# 对(3, 6)做标注
plt.annotate("(3, 6)",
             xy=(3, 9),       # 在(3.3, 5.5)上做标注
             fontsize=16,         # 设置字体大小为 16
             xycoords='data')  # xycoords='data' 是说基于数据的值来选位置


# 对(3, 0)做标注
plt.text(2.3, 2.6, "this point very important", # 2.3, 2.6 是相对位置
         fontdict={'size': 12, 'color': 'blue'})  # fontdict设置文本字体


plt.show() # 呈现图片

# %% [markdown]
# ### 上文介绍了 matplotlib 的基本使用方法
# ### 现在开始使用复杂一点的数据（直接导入 seaborn 包里的数据）
# matplotlib 和 seaborn 的关系：底层的 Matplotlib 库和较高层的 Seaborn 库实现数据可视化

# %%
# seaborn use see https://seaborn.pydata.org/tutorial/regression.html
tips = sns.load_dataset("tips")
tips[:10]

# continuous and categorical variable
# total_bill 总账单
# tip 消费
# sex 性别
# smoker 是否吸烟
# day 日期（星期x）
# time （午饭/晚饭）
# size 人数
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# sns.histplot 直方图的具体参数

# %%
# 如果报错：AttributeError: module 'seaborn' has no attribute 'histplot'，
# 在这里加上：pip install -U seaborn
# 然后重启 notebook


plt.figure(figsize = (20, 12)) 
fig, axes = plt.subplots(1, 2) # 1*2的格子

sns.histplot(tips, # dataset
            x = "size",
            hue ="time", # 颜色
            multiple ="dodge", # 尝试一下 multiple ="stack"
            discrete = True, # 尝试一下改成 False
            palette="rocket", # seaborn 自己的 palette # see https://seaborn.pydata.org/tutorial/color_palettes.html?highlight=palette
            bins=[1, 2, 3, 4, 5, 6],
            stat='count', #stat = "density" 
            ax=axes[0]) # 看一下，这里的

# 我们看到的是在某一餐，每桌有几个人的分布

sns.histplot(tips, 
            x = "size",
            hue ="time", 
            multiple ="stack", # 尝试一下 multiple ="stack"
            discrete = True, # are centered on their corresponding data points
            palette="rocket", # seaborn 自己的 palette
            bins=[1, 2, 3, 4, 5, 6],
            stat='count',
            ax=axes[1])


plt.text(4, 50, "hi this is annotation", #hi \nthis \nis \nannotation
         horizontalalignment='left', 
         fontsize = 10, 
         color='blue', 
         weight='bold') #light

plt.show()

# %%
# what's the relationship between total bill and tip? （bivariate）
# 我们需要使用scatterplot：散点图

sns.scatterplot #查看参数
# Out:
# <function seaborn.relational.scatterplot(*, x=None, y=None, hue=None, style=None, size=None, data=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, x_bins=None, y_bins=None, units=None, estimator=None, ci=95, n_boot=1000, alpha=None, x_jitter=None, y_jitter=None, legend='auto', ax=None, **kwargs)>

# %%
plt.figure(figsize = (20, 12)) 
fig, axes = plt.subplots(1, 2)
sns.scatterplot(x="total_bill", 
            y="tip", 
            data=tips,
            ax = axes[0]) # 左侧图一



# 要怎么修改 label 呢？
sns.scatterplot(x="total_bill", 
            y="tip", 
            data=tips,
            ax = axes[1]) # 右侧图二

# 加入这两行代码：
plt.xlabel("amount of total bill") 
plt.ylabel("amount of tip")


fig.tight_layout()
plt.show()

# %%
# regression table 回归分析表
# 如何建立回归分析图？

sns.regplot(x = "total_bill", 
            y = "tip", 
            data = tips) # 95% CI

plt.show()

# %% [markdown]
# - 引入其他变量是否会对y~x的关系产生影响？

# %%
# adjust regression table
# lmplot vs regplot

# While regplot() always shows a single relationship, 
# lmplot() combines regplot() with FacetGrid to provide an easy interface 
# to show a linear regression on “faceted” plots 
# that allow you to explore interactions with up to three additional categorical variables.
# https://seaborn.pydata.org/tutorial/regression.html

# %%
sns.lmplot(x = "size", # variable name：size of diners
           y = "tip", # variable name
           hue = "smoker", # condition on other variables
           data = tips, # data source 
           markers = ["o", "x"], 
           palette = "Set2") # 调色盘) #showing means and confidence intervals for unique values

# %%
sns.lmplot(x = "size", # variable name：size of diners
           y = "tip", # variable name
           hue = "smoker", # condition on other variables
           data = tips, # data source 
           markers = ["o", "x"], 
           palette = "Set2", # 调色盘
           x_estimator = np.mean) #showing means and confidence intervals for unique values

# %%
# another variable
sns.lmplot(x = "size", # variable name：size of diners
           y = "tip", # variable name
           hue = "smoker", # condition on other variables
           data = tips, # data source 
           markers = ["o", "x"], 
           palette = "Set2", # 调色盘
           col = "time", # compare time of the meal
           x_estimator = np.mean) #showing means and confidence intervals for unique values
plt.show()

# %%
# 并排回归模型图
my_own_colors = ["#660874", "#4374B3"] # 还记得之前的选色吗？#660874是清华紫
sns.set_palette(sns.color_palette(my_own_colors))

# 用 pairplot 实现
sns.pairplot(tips, 
             x_vars=["total_bill", "size"], 
             y_vars=["tip"],
             hue="smoker",
             height= 5, 
             aspect=.8, # aspect * height = width
             kind = "reg", #‘scatter’, ‘kde’, ‘hist’, ‘reg’
             palette = my_own_colors)

# %% [markdown]
# ### 如何绘制地图？

# %%
import geopandas as gpd # 引入geopandas的包
china = gpd.read_file('CN-shi-A.shp') # 请大家在绘制中国地图时一定要选择标准的中国地图的shapefile
china[:10] # 查看一下这个数据的细节内容
# Out:
#            AREA  PERIMETER  SHI_D_  SHI_D_ID     SHI  OID_        F4  \
# 0  6.476870e+10  1782900.0       2         1  232700    71      黑龙江省
# 1  2.527840e+11  3853430.0       3         2  150700    30    内蒙古自治区
# 2  6.687090e+10  1858220.0       4         3  231100    69      黑龙江省
# 3  3.280340e+10  1585770.0       5         4  230700    65      黑龙江省
# 4  3.247440e+10  2015700.0       6         5  230800    66      黑龙江省
# 5  1.466300e+10   917378.0       7         6  230400    62      黑龙江省
# 6  2.205040e+10  1318110.0       8         7  230500    63      黑龙江省
# 7  4.225410e+10  1755410.0       9         8  230200    60      黑龙江省
# 8  1.167980e+11  2096580.0      10         9  654300   337  新疆维吾尔自治区
# 9  3.490010e+10  1657040.0      11        10  231200    70      黑龙江省
#
#   CityNameC   sheng                                           geometry
# 0    大兴安岭地区  230000  POLYGON ((1253906.625 5918214.500, 1254006.625...
# 1     呼伦贝尔市  150000  POLYGON ((1136043.500 5872123.500, 1136065.500...
# 2       黑河市  230000  POLYGON ((1564918.875 5698373.500, 1564934.500...
# 3       伊春市  230000  POLYGON ((1765475.375 5564999.500, 1765499.750...
# 4      佳木斯市  230000  POLYGON ((2127554.000 5541472.500, 2127628.000...
# 5       鹤岗市  230000  POLYGON ((1899806.750 5483524.500, 1899871.750...
# 6      双鸭山市  230000  POLYGON ((2184877.000 5459670.500, 2184860.750...
# 7     齐齐哈尔市  230000  POLYGON ((1527346.000 5417926.000, 1527412.125...
# 8     阿勒泰地区  650000  POLYGON ((-1330250.250 5440838.500, -1330231.1...
# 9       绥化市  230000  POLYGON ((1715412.000 5405606.000, 1715507.625...

# %%
# 看一下最简单粗暴的图

plt.rc('xtick', labelsize=small) # 重新设置x的scale   
plt.rc('ytick', labelsize=small) # 重新设置y的scale

plt.rcParams['figure.figsize'] = [8, 8] # 设置图片大小

china.plot(color='red') # 直接data.plot()

plt.annotate(r"Map of China", 
             xy=(-1500000, 1500000), # 放置标注的坐标系
             size = 16) 
fig.tight_layout()
plt.show()

# %%
zhejiang = china.loc[china.F4.isin(['浙江省']), ['CityNameC', 'geometry']] # 筛选浙江省的列，地级市与geometry数据
zhejiang[:10] # 查看前十条数据的结构

# cr:部分代码参考 https://zhuyuhao.com/2020/10/25/data-map-2/
# Out:
#      CityNameC                                           geometry
# 1012       舟山市  POLYGON ((1661577.875 3417107.250, 1661529.750...
# 1013       舟山市  POLYGON ((1661682.125 3416897.500, 1661624.750...
# 1014       舟山市  POLYGON ((1659743.000 3415881.000, 1659790.875...
# 1016       舟山市  POLYGON ((1661424.125 3413895.000, 1661173.000...
# 1017       舟山市  POLYGON ((1661431.875 3413682.000, 1661327.375...
# 1018       舟山市  POLYGON ((1662421.625 3413025.500, 1662319.875...
# 1019       舟山市  POLYGON ((1656718.625 3412400.000, 1656598.875...
# 1020       舟山市  POLYGON ((1656809.125 3412116.750, 1656957.125...
# 1021       舟山市  POLYGON ((1652252.500 3412095.000, 1652194.500...
# 1022       舟山市  POLYGON ((1667404.375 3411848.250, 1667363.000...

# %%
# 进一步查看数据情况
zhejiang['CityNameC'].value_counts() # 查看一下地级市的数据是怎么样的？想想为什么各个地级市差异这么大？反映了地理图例的什么特点？
# Out:
# 舟山市    666
# 宁波市    272
# 台州市    217
# 温州市    213
# 杭州市      1
# 湖州市      1
# 衢州市      1
# 绍兴市      1
# 嘉兴市      1
# 丽水市      1
# 金华市      1
# Name: CityNameC, dtype: int64

# %%
# polygon 到底是什么？
print(zhejiang.iloc[2,0], zhejiang.iloc[2,1])
zhejiang.iloc[2,1]
# Out:
# 舟山市 POLYGON ((1659743 3415881, 1659790.875 3415858.75, 1659843.875 3415930.25, 1659900.5 3415953, 1659963.125 3415914.25, 1659976.25 3415837.25, 1659950.375 3415765.5, 1660022.375 3415658, 1660301.375 3415433, 1660416.25 3415360.25, 1660513.625 3415367.75, 1660570 3415420.25, 1660668.5 3415551.75, 1660671.75 3415712, 1660633.75 3415764.75, 1660554.625 3415843, 1660480.25 3415934.5, 1660442.125 3415988.5, 1660434.375 3416043.75, 1660488.125 3416041, 1660545.25 3416008.25, 1660633.75 3415931.75, 1660692.375 3415967.25, 1660746.875 3415989.5, 1660800.375 3415948.75, 1660848.125 3415894.75, 1660895.5 3415875.5, 1660958.125 3415848.75, 1661045.375 3415847.25, 1661083 3415898.5, 1661060 3416026.25, 1661126.875 3416061.25, 1661259.125 3415956.5, 1661331.125 3415889.25, 1661387.125 3415847, 1661467.875 3415801, 1661528 3415804.75, 1661577.375 3415786, 1661633.125 3415728.25, 1661667 3415674.75, 1661690.5 3415596.5, 1661642.5 3415538.25, 1661623.5 3415412.25, 1661657.375 3415244.25, 1661576.75 3415204.75, 1661513.25 3415236.5, 1661439.875 3415310.5, 1661375.125 3415401.75, 1661325.125 3415427.75, 1661260.875 3415378.75, 1661191.25 3415346.5, 1661132.25 3415393.25, 1661087.25 3415440.75, 1661028.25 3415475.25, 1660949.5 3415466, 1660894.5 3415409.75, 1660867.5 3415352.25, 1660870 3415257.75, 1660884 3415203.75, 1660959.625 3415146.5, 1661004.5 3415100, 1661036.625 3415023.5, 1661011.5 3414946.75, 1660958.625 3414932, 1660905.625 3414958.25, 1660915.125 3414775.5, 1660959.125 3414550.75, 1660922.75 3414485.25, 1660866.625 3414443.25, 1660808.625 3414485, 1660792.875 3414589.25, 1660736.25 3414594.5, 1660672.875 3414540.5, 1660629.5 3414565.75, 1660571.875 3414605.5, 1660516 3414635.5, 1660459 3414598.25, 1660462.625 3414497, 1660443 3414398.5, 1660413.625 3414305.5, 1660344.625 3414253.75, 1660237.625 3414242.5, 1660157 3414288.5, 1660087.875 3414338.75, 1660026.5 3414452.25, 1659996.375 3414502.25, 1659947.5 3414533.5, 1659770.375 3414517.75, 1659729.125 3414478.25, 1659669.375 3414432.25, 1659552 3414409.75, 1659501.375 3414423, 1659427.625 3414430.25, 1659329.5 3414475, 1659224.625 3414509.5, 1659152.375 3414521, 1659036.75 3414516.25, 1658983.875 3414526.25, 1658937.5 3414555.75, 1658890.125 3414729.5, 1658796.5 3414713.5, 1658658.375 3414684, 1658587 3414718.5, 1658528.75 3414733.5, 1658457.625 3414739, 1658388.75 3414771.75, 1658409.25 3414877.5, 1658412.25 3414942, 1658321.375 3414975.75, 1658150.875 3414983.75, 1658098.25 3415004, 1658094.75 3415068.25, 1658173.625 3415130, 1658250.625 3415173, 1658337.875 3415189, 1658416 3415169.25, 1658503.875 3415140, 1658648.25 3415142.75, 1658798.375 3415186.75, 1658849.375 3415183.75, 1658891.875 3415151.25, 1658936 3415121.25, 1658961 3415173.25, 1659033.375 3415255.5, 1659059.75 3415299.5, 1659012.125 3415348.5, 1658978.875 3415415.5, 1658896.875 3415456.25, 1658840.125 3415463.25, 1658775 3415516.25, 1658750.75 3415597.5, 1658775 3415666.75, 1658760.125 3415753.75, 1658697.25 3415822.5, 1658599.25 3415924.25, 1658556.625 3415974, 1658548.125 3416025, 1658565 3416077.5, 1658649.75 3416135.25, 1658702.75 3416206.75, 1658697.25 3416265.5, 1658664.25 3416372, 1658741.375 3416455, 1658800.5 3416480.25, 1658875.25 3416508.5, 1658936.375 3416546.5, 1658974.875 3416588.5, 1659031.125 3416491.5, 1659028.75 3416391.25, 1659092.625 3416345.25, 1659131.875 3416302, 1659179.375 3416225, 1659319 3416245.5, 1659376 3416193, 1659429.875 3416092.75, 1659466.375 3416011.75, 1659491.125 3415963.75, 1659602.875 3415948, 1659743 3415881))

# %%
# dissolve - e.g. 根据城市名，把所有碎片拼起来

zhejiang_bycity = zhejiang.dissolve(by = 'CityNameC')
zhejiang_bycity
# Out:
#                                                     geometry
# CityNameC
# 丽水市        POLYGON ((1484571.750 3156666.250, 1484455.750...
# 台州市        MULTIPOLYGON (((1569555.000 3078540.750, 15696...
# 嘉兴市        POLYGON ((1490737.875 3405759.000, 1491758.750...
# 宁波市        MULTIPOLYGON (((1657153.875 3188577.500, 16570...
# 杭州市        POLYGON ((1443427.000 3341720.500, 1444503.625...
# 温州市        MULTIPOLYGON (((1554861.750 2965744.500, 15548...
# 湖州市        POLYGON ((1378345.250 3405663.250, 1378369.625...
# 绍兴市        POLYGON ((1500964.125 3322649.500, 1501510.750...
# 舟山市        MULTIPOLYGON (((1633678.125 3268518.000, 16336...
# 衢州市        POLYGON ((1275760.000 3199015.250, 1275824.875...
# 金华市        POLYGON ((1427058.000 3243295.250, 1427269.000...

# %%
# 查看整个shape file
zhejiang_bycity.plot(color='green')
plt.annotate(r"Zhejiang province", 
             xy=(1600000, 3000000),
             size = 10)
fig.tight_layout()
plt.show()

# %%
data_list = [['杭州市', 18109, '8.5%'],
                                      ['宁波市', 14594.9, '8.2%'],
                                      ['温州市', 7585, '7.7%'],
                                      ['湖州市', 3644.9, '9.5%'],
                                      ['嘉兴市', 6355.28, '8.5%'],
                                      ['绍兴市', 6795, '8.7%'],
                                      ['金华市', 5355.44, '9.8%'],
                                      ['衢州市', 1875.61, '8.7%'],
                                      ['舟山市', 1703.62, '8.4%'],
                                      ['台州市', 5786.19, '8.3%'],
                                      ['丽水市', 1710.03, '8.3%']]

data_gdp_increase = pd.DataFrame(data_list, columns = ['CityNameC', 'gdp', 'increase'])
data_gdp_increase
# Out:
#    CityNameC       gdp increase
# 0        杭州市  18109.00     8.5%
# 1        宁波市  14594.90     8.2%
# 2        温州市   7585.00     7.7%
# 3        湖州市   3644.90     9.5%
# 4        嘉兴市   6355.28     8.5%
# 5        绍兴市   6795.00     8.7%
# 6        金华市   5355.44     9.8%
# 7        衢州市   1875.61     8.7%
# 8        舟山市   1703.62     8.4%
# 9        台州市   5786.19     8.3%
# 10       丽水市   1710.03     8.3%

# %%
# 如何合并两个的dataset？
print('length of dataset zhejiang:', len(zhejiang_bycity), '\nlength of dataset data_gdp_increase:', len(data_gdp_increase))

zhejiang_bycity = zhejiang_bycity.merge(data_gdp_increase, on='CityNameC')
zhejiang_bycity # 合成出来的表

# 把两个列表里的内容在了一个表里
# Out:
# length of dataset zhejiang: 11
# length of dataset data_gdp_increase: 11
#    CityNameC                                           geometry       gdp  \
# 0        丽水市  POLYGON ((1484571.750 3156666.250, 1484455.750...   1710.03
# 1        台州市  MULTIPOLYGON (((1569555.000 3078540.750, 15696...   5786.19
# 2        嘉兴市  POLYGON ((1490737.875 3405759.000, 1491758.750...   6355.28
# 3        宁波市  MULTIPOLYGON (((1657153.875 3188577.500, 16570...  14594.90
# 4        杭州市  POLYGON ((1443427.000 3341720.500, 1444503.625...  18109.00
# 5        温州市  MULTIPOLYGON (((1554861.750 2965744.500, 15548...   7585.00
# 6        湖州市  POLYGON ((1378345.250 3405663.250, 1378369.625...   3644.90
# 7        绍兴市  POLYGON ((1500964.125 3322649.500, 1501510.750...   6795.00
# 8        舟山市  MULTIPOLYGON (((1633678.125 3268518.000, 16336...   1703.62
# 9        衢州市  POLYGON ((1275760.000 3199015.250, 1275824.875...   1875.61
# 10       金华市  POLYGON ((1427058.000 3243295.250, 1427269.000...   5355.44
#
#    increase
# 0      8.3%
# 1      8.3%
# 2      8.5%
# 3      8.2%
# 4      8.5%
# 5      7.7%
# 6      9.5%
# 7      8.7%
# 8      8.4%
# 9      8.7%
# 10     9.8%

# %%
# plot zhejiang

fig, ax = plt.subplots(1, figsize=(10, 10))

zhejiang_bycity.plot(
    column = 'gdp', # 图例上按照颜色显示的数据,'increase'
    cmap = 'YlGnBu', # https://matplotlib.org/stable/tutorials/colors/colormaps.html # 颜色使用
    scheme ='NaturalBreaks', # 'Percentiles'/'JenksCaspall' Classification Schemes for Choropleth Maps 如何匹配数值和颜色
    linewidth = 1, 
    edgecolor = '0.25', # 0?1?
    ax=ax,
    legend = True)
ax.axis('off') # 这行删掉？


# add legend
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.15,0.5))
leg.set_title('gdp\n')

plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(10, 10))

zhejiang_bycity.plot(
    column = 'gdp', 
    cmap = 'autumn', # https://matplotlib.org/stable/tutorials/colors/colormaps.html # 颜色使用
    scheme ='JenksCaspall', # 'Percentiles'/'JenksCaspall' Classification Schemes for Choropleth Maps 如何匹配数值和颜色
    linewidth = 1, 
    edgecolor = 'grey', 
    ax=ax,
    legend = True,
    legend_kwds = {'borderpad': 0.25, 
                   'fontsize':9}) 

    # 我们正在使用 geopandas 作图, 在 bing.com 检索 geopandas dataframe plot
    # -> 打开 geopandas 的官方文件，看看里面有没有提到 legend - legend_kwds
    # https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.plot.html
    # 看到 legend_kwds的部分写道，Keyword arguments to pass to matplotlib.pyplot.legend()
    # 所以可以查找 matplotlib.pyplot.legend() 的官方文档 https://matplotlib.org/stable/api/legend_api.html
    # 关键词检索 size：-> borderpad -> The fractional whitespace inside the legend border, in font-size units. 
    # 也可以通过font-size调整：fontsizeint or {'xx-small', 'x-small', 'small', 'medium', 'large', 'x-large', 'xx-large'}
    
    
#ax.axis('off')


# 接下来要做什么 - 要把对应的区域填充进去

for index, row in zhejiang_bycity.iterrows():# 遍历每一行
    xy = row['geometry'].centroid.coords[:]
    print(row['CityNameC'], '的中心点为：', xy[0])
    ax.annotate(row['CityNameC'], # 具体annotation的内容：如xx市
                xy=xy[0], # annotation的位置
                horizontalalignment='center', # 水平对齐
                verticalalignment='center', # 垂直对齐
                fontproperties=zhfont,
                color = 'black',
                size = 13)
    
ax.set_title('浙江省2021年gdp分布', 
             fontproperties=zhfont, size = 16, color = 'red', weight = 'bold')

# add legend 可以理解成提取+移动 legend 的过程
leg = ax.get_legend() # get legend
leg.set_bbox_to_anchor((0.26,1)) # 设置legend坐标
leg.set_title('GDP')


plt.show()
# Out:
# 丽水市 的中心点为： (1407853.8195477396, 3073099.4680108386)
# 台州市 的中心点为： (1550735.8291555862, 3160541.189233611)
# 嘉兴市 的中心点为： (1489229.7816611573, 3359659.928723038)
# 宁波市 的中心点为： (1566779.7640519505, 3272479.253881712)
# 杭州市 的中心点为： (1376116.9174347352, 3260926.5939173535)
# 温州市 的中心点为： (1501796.66817099, 3054008.8440600326)
# 湖州市 的中心点为： (1399704.6285704314, 3360329.0396883856)
# 绍兴市 的中心点为： (1489243.5236624174, 3259419.9847740503)
# 舟山市 的中心点为： (1628808.0492224635, 3323034.3520094887)
# 衢州市 的中心点为： (1315959.8156653412, 3143021.1395433857)
# 金华市 的中心点为： (1434893.877181759, 3180995.5523161096)

# %% [markdown]
# ### 感谢大家！：D
